# %%
from utils.utils import LMDataset
import torch
from torch.utils.data import DataLoader
from utils.utils import Vectorizer
from lms.models import FFNLM
from pathlib import Path
import os

# %%
data_folder = Path.cwd() / Path('..').resolve() / Path('data', 'clean')

# %%
print('Loading corpus...')
texto = ''
lista_textos = [f for f in os.listdir(data_folder) if f.split('.')[-1] == 'txt']
for wiki_txt in lista_textos:
    print(f'\tReading {wiki_txt}...')
    with open(data_folder / Path(wiki_txt), encoding='utf-8') as fp:
        texto += fp.read()
    fp.close()
    print(f'¡Ok! Texto de longitud {len(texto.split())}')
# Out:
# Loading corpus...
# 	Reading wiki_perro_clean_1.txt...
# ¡Ok! Texto de longitud 7113

# %%
# --------------------------------------
# Loading Language Model
# --------------------------------------
window_length = 2
batch_size = 2
lm = FFNLM(vectorizer=Vectorizer(texto),
           window_length=window_length,
           hidden_size=20)
print('vocabulary_size: ',lm.vocabulary_size)
#print('vocabulary: ',lm.vectorizer.tokens)
# Out:
# vocabulary_size:  2122

# %%
lm.vectorizer.get_tokens('1.')
# Out:
# ['1', '.']

# %%
print('1.' in lm.vectorizer.tokens)
# Out:
# True

# %%
lm.code_context(['1.', 'frente']).shape
# Out:
# shape_context:  (2,)
# torch.Size([1, 6366])

# %%
lm.vectorizer.get_tokens(' '.join(['1.', 'frente']))
# Out:
# ['1', '.', 'frente']

# %%
print(' '.join(['1.', 'frente']))
# Out:
# 1. frente

# %%
# --------------------------------------
# Training
# --------------------------------------
parameters = {"learning_rate":1e-4,
            "window_length":window_length,
            "batch_size":batch_size,
            "num_epochs":50
}
print('Training...')
lm.train(texto=texto, parametros=parameters)
lm.save_model()
# Out:
# Training...
#   0%|                                                                                                  | 0/50 [00:00<?, ?it/s]
# batch_index:  50 ds_features:  [['pelaje', 'es'], ['es', 'muy']]
# porcentaje_batch_index:  1.27 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  51 ds_features:  [['muy', 'diverso'], ['diverso', 'y']]
# porcentaje_batch_index:  1.29 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  52 ds_features:  [['y', 'varía'], ['varía', 'según']]
# porcentaje_batch_index:  1.32 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  53 ds_features:  [['según', 'la'], ['la', 'raza']]
# porcentaje_batch_index:  1.34 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  54 ds_features:  [['raza', '.'], ['.', 'posee']]
# porcentaje_batch_index:  1.37 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  55 ds_features:  [['posee', 'un'], ['un', 'oído']]
# porcentaje_batch_index:  1.39 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  56 ds_features:  [['oído', 'y'], ['y', 'un']]
# porcentaje_batch_index:  1.42 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  57 ds_features:  [['un', 'olfato'], ['olfato', 'muy']]
# porcentaje_batch_index:  1.44 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  58 ds_features:  [['muy', 'desarrollados'], ['desarrollados', ',']]
# porcentaje_batch_index:  1.47 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  59 ds_features:  [[',', 'y'], ['y', 'este']]
# porcentaje_batch_index:  1.49 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  60 ds_features:  [['este', 'último'], ['último', 'es']]
# porcentaje_batch_index:  1.52 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  61 ds_features:  [['es', 'su'], ['su', 'principal']]
# porcentaje_batch_index:  1.54 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  62 ds_features:  [['principal', 'órgano'], ['órgano', 'sensorial']]
# porcentaje_batch_index:  1.57 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  63 ds_features:  [['sensorial', '.'], ['.', 'su']]
# porcentaje_batch_index:  1.59 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  64 ds_features:  [['su', 'longevidad'], ['longevidad', 'media']]
# porcentaje_batch_index:  1.62 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  65 ds_features:  [['media', 'es'], ['es', 'de']]
# porcentaje_batch_index:  1.65 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  66 ds_features:  [['de', 'diez'], ['diez', 'a']]
# porcentaje_batch_index:  1.67 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  67 ds_features:  [['a', 'trece'], ['trece', 'años']]
# porcentaje_batch_index:  1.7 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  68 ds_features:  [['años', ','], [',', 'dependiendo']]
# porcentaje_batch_index:  1.72 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  69 ds_features:  [['dependiendo', 'de'], ['de', 'la']]
# porcentaje_batch_index:  1.75 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  70 ds_features:  [['la', 'raza'], ['raza', '.']]
# porcentaje_batch_index:  1.77 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  71 ds_features:  [['.', 'junto'], ['junto', 'al']]
# porcentaje_batch_index:  1.8 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  72 ds_features:  [['al', 'gato'], ['gato', 'doméstico']]
# porcentaje_batch_index:  1.82 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  73 ds_features:  [['doméstico', ','], [',', 'se']]
# porcentaje_batch_index:  1.85 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  74 ds_features:  [['se', 'le'], ['le', 'considera']]
# porcentaje_batch_index:  1.87 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  75 ds_features:  [['considera', 'uno'], ['uno', 'de']]
# porcentaje_batch_index:  1.9 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  76 ds_features:  [['de', 'los'], ['los', 'animales']]
# porcentaje_batch_index:  1.92 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  77 ds_features:  [['animales', 'de'], ['de', 'compañía']]
# porcentaje_batch_index:  1.95 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  78 ds_features:  [['compañía', 'más'], ['más', 'populares']]
# porcentaje_batch_index:  1.97 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  79 ds_features:  [['populares', 'del'], ['del', 'mundo']]
# porcentaje_batch_index:  2.0 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  80 ds_features:  [['mundo', '.'], ['.', 'el']]
# porcentaje_batch_index:  2.02 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  81 ds_features:  [['el', 'perro'], ['perro', 'doméstico']]
# porcentaje_batch_index:  2.05 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  82 ds_features:  [['doméstico', 'proviene'], ['proviene', 'de']]
# porcentaje_batch_index:  2.08 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  83 ds_features:  [['de', 'un'], ['un', 'grupo']]
# porcentaje_batch_index:  2.1 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  84 ds_features:  [['grupo', 'ancestral'], ['ancestral', 'común']]
# porcentaje_batch_index:  2.13 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  85 ds_features:  [['común', 'que'], ['que', 'data']]
# porcentaje_batch_index:  2.15 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  86 ds_features:  [['data', 'de'], ['de', 'hace']]
# porcentaje_batch_index:  2.18 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  87 ds_features:  [['hace', 'aproximadamente'], ['aproximadamente', 'treinta']]
# porcentaje_batch_index:  2.2 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  88 ds_features:  [['treinta', 'mil'], ['mil', 'años']]
# porcentaje_batch_index:  2.23 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  89 ds_features:  [['años', ','], [',', 'y']]
# porcentaje_batch_index:  2.25 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  90 ds_features:  [['y', 'desde'], ['desde', 'entonces']]
# porcentaje_batch_index:  2.28 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  91 ds_features:  [['entonces', 'se'], ['se', 'ha']]
# porcentaje_batch_index:  2.3 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  92 ds_features:  [['ha', 'extendido'], ['extendido', 'a']]
# porcentaje_batch_index:  2.33 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  93 ds_features:  [['a', 'todas'], ['todas', 'partes']]
# porcentaje_batch_index:  2.35 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  94 ds_features:  [['partes', 'del'], ['del', 'mundo']]
# porcentaje_batch_index:  2.38 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  95 ds_features:  [['mundo', '.'], ['.', 'los']]
# porcentaje_batch_index:  2.4 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  96 ds_features:  [['los', 'primeros'], ['primeros', 'restos']]
# porcentaje_batch_index:  2.43 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  97 ds_features:  [['restos', 'fósiles'], ['fósiles', 'de']]
# porcentaje_batch_index:  2.46 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  98 ds_features:  [['de', 'perros'], ['perros', 'enterrados']]
# porcentaje_batch_index:  2.48 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  99 ds_features:  [['enterrados', 'junto'], ['junto', 'con']]
# porcentaje_batch_index:  2.51 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  100 ds_features:  [['con', 'seres'], ['seres', 'humanos']]
# porcentaje_batch_index:  2.53 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  101 ds_features:  [['humanos', 'se'], ['se', 'encontraron']]
# porcentaje_batch_index:  2.56 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  102 ds_features:  [['encontraron', 'en'], ['en', 'israel']]
# porcentaje_batch_index:  2.58 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  103 ds_features:  [['israel', ','], [',', 'y']]
# porcentaje_batch_index:  2.61 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  104 ds_features:  [['y', 'datan'], ['datan', 'de']]
# porcentaje_batch_index:  2.63 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  105 ds_features:  [['de', 'hace'], ['hace', 'unos']]
# porcentaje_batch_index:  2.66 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  106 ds_features:  [['unos', 'doce'], ['doce', 'mil']]
# porcentaje_batch_index:  2.68 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  107 ds_features:  [['mil', 'años'], ['años', '.']]
# porcentaje_batch_index:  2.71 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  108 ds_features:  [['.', 'desde'], ['desde', 'entonces']]
# porcentaje_batch_index:  2.73 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  109 ds_features:  [['entonces', ','], [',', 'los']]
# porcentaje_batch_index:  2.76 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  110 ds_features:  [['los', 'perros'], ['perros', 'y']]
# porcentaje_batch_index:  2.78 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  111 ds_features:  [['y', 'los'], ['los', 'humanos']]
# porcentaje_batch_index:  2.81 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  112 ds_features:  [['humanos', 'han'], ['han', 'evolucionado']]
# porcentaje_batch_index:  2.83 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  113 ds_features:  [['evolucionado', 'conjuntamente'], ['conjuntamente', ',']]
# porcentaje_batch_index:  2.86 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  114 ds_features:  [[',', 'tanto'], ['tanto', 'en']]
# porcentaje_batch_index:  2.89 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  115 ds_features:  [['en', 'las'], ['las', 'culturas']]
# porcentaje_batch_index:  2.91 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  116 ds_features:  [['culturas', 'africanas'], ['africanas', 'y']]
# porcentaje_batch_index:  2.94 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  117 ds_features:  [['y', 'euroasiáticas'], ['euroasiáticas', ',']]
# porcentaje_batch_index:  2.96 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  118 ds_features:  [[',', 'como'], ['como', 'en']]
# porcentaje_batch_index:  2.99 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  119 ds_features:  [['en', 'las'], ['las', 'que']]
# porcentaje_batch_index:  3.01 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  120 ds_features:  [['que', 'poblaron'], ['poblaron', 'américa']]
# porcentaje_batch_index:  3.04 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  121 ds_features:  [['américa', 'y'], ['y', 'se']]
# porcentaje_batch_index:  3.06 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  122 ds_features:  [['se', 'mantuvieron'], ['mantuvieron', 'sin']]
# porcentaje_batch_index:  3.09 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  123 ds_features:  [['sin', 'contacto'], ['contacto', 'con']]
# porcentaje_batch_index:  3.11 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  124 ds_features:  [['con', 'aquellas'], ['aquellas', 'hasta']]
# porcentaje_batch_index:  3.14 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  125 ds_features:  [['hasta', 'el'], ['el', 'siglo']]
# porcentaje_batch_index:  3.16 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  126 ds_features:  [['siglo', 'xv'], ['xv', '.']]
# porcentaje_batch_index:  3.19 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  127 ds_features:  [['.', 'los'], ['los', 'perros']]
# porcentaje_batch_index:  3.21 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  128 ds_features:  [['perros', 'comparten'], ['comparten', 'el']]
# porcentaje_batch_index:  3.24 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  129 ds_features:  [['el', 'entorno'], ['entorno', ',']]
# porcentaje_batch_index:  3.26 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  130 ds_features:  [[',', 'los'], ['los', 'hábitos']]
# porcentaje_batch_index:  3.29 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  131 ds_features:  [['hábitos', 'y'], ['y', 'el']]
# porcentaje_batch_index:  3.32 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  132 ds_features:  [['el', 'estilo'], ['estilo', 'de']]
# porcentaje_batch_index:  3.34 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  133 ds_features:  [['de', 'vida'], ['vida', 'humanos']]
# porcentaje_batch_index:  3.37 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  134 ds_features:  [['humanos', ','], [',', 'como']]
# porcentaje_batch_index:  3.39 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  135 ds_features:  [['como', 'las'], ['las', 'dietas']]
# porcentaje_batch_index:  3.42 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  136 ds_features:  [['dietas', 'ricas'], ['ricas', 'en']]
# porcentaje_batch_index:  3.44 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  137 ds_features:  [['en', 'cereales'], ['cereales', 'y']]
# porcentaje_batch_index:  3.47 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  138 ds_features:  [['y', 'almidón'], ['almidón', '.']]
# porcentaje_batch_index:  3.49 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  139 ds_features:  [['.', 'la'], ['la', 'alimentación']]
# porcentaje_batch_index:  3.52 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  140 ds_features:  [['alimentación', 'inadecuada'], ['inadecuada', ',']]
# porcentaje_batch_index:  3.54 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  141 ds_features:  [[',', 'así'], ['así', 'como']]
# porcentaje_batch_index:  3.57 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  142 ds_features:  [['como', 'el'], ['el', 'uso']]
# porcentaje_batch_index:  3.59 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  143 ds_features:  [['uso', 'de'], ['de', 'antibióticos']]
# porcentaje_batch_index:  3.62 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  144 ds_features:  [['antibióticos', ','], [',', 'son']]
# porcentaje_batch_index:  3.64 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  145 ds_features:  [['son', 'la'], ['la', 'causa']]
# porcentaje_batch_index:  3.67 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  146 ds_features:  [['causa', 'del'], ['del', 'desarrollo']]
# porcentaje_batch_index:  3.7 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  147 ds_features:  [['desarrollo', 'de'], ['de', 'muchas']]
# porcentaje_batch_index:  3.72 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  148 ds_features:  [['muchas', 'enfermedades'], ['enfermedades', 'inflamatorias']]
# porcentaje_batch_index:  3.75 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  149 ds_features:  [['inflamatorias', 'e'], ['e', 'inmunológicas']]
# porcentaje_batch_index:  3.77 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  150 ds_features:  [['inmunológicas', '.'], ['.', 'unas']]
# porcentaje_batch_index:  3.8 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  151 ds_features:  [['unas', 'cuatrocientas'], ['cuatrocientas', 'enfermedades']]
# porcentaje_batch_index:  3.82 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  152 ds_features:  [['enfermedades', 'del'], ['del', 'perro']]
# porcentaje_batch_index:  3.85 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  153 ds_features:  [['perro', 'tienen'], ['tienen', 'una']]
# porcentaje_batch_index:  3.87 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  154 ds_features:  [['una', 'equivalente'], ['equivalente', 'humana']]
# porcentaje_batch_index:  3.9 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  155 ds_features:  [['humana', ','], [',', 'y']]
# porcentaje_batch_index:  3.92 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  156 ds_features:  [['y', 'destacan'], ['destacan', 'especialmente']]
# porcentaje_batch_index:  3.95 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  157 ds_features:  [['especialmente', 'la'], ['la', 'enfermedad']]
# porcentaje_batch_index:  3.97 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  158 ds_features:  [['enfermedad', 'de'], ['de', 'alzheimer']]
# porcentaje_batch_index:  4.0 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  159 ds_features:  [['alzheimer', 'y'], ['y', 'otros']]
# porcentaje_batch_index:  4.02 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  160 ds_features:  [['otros', 'trastornos'], ['trastornos', 'neurológicos']]
# porcentaje_batch_index:  4.05 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  161 ds_features:  [['neurológicos', ','], [',', 'así']]
# porcentaje_batch_index:  4.07 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  162 ds_features:  [['así', 'como'], ['como', 'varios']]
# porcentaje_batch_index:  4.1 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  163 ds_features:  [['varios', 'tipos'], ['tipos', 'de']]
# porcentaje_batch_index:  4.13 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  164 ds_features:  [['de', 'cáncer'], ['cáncer', ',']]
# porcentaje_batch_index:  4.15 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  165 ds_features:  [[',', 'enfermedades'], ['enfermedades', 'autoinmunes']]
# porcentaje_batch_index:  4.18 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  166 ds_features:  [['autoinmunes', 'y'], ['y', 'enfermedades']]
# porcentaje_batch_index:  4.2 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  167 ds_features:  [['enfermedades', 'cardiovasculares'], ['cardiovasculares', '.']]
# porcentaje_batch_index:  4.23 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  168 ds_features:  [['.', 'los'], ['los', 'perros']]
# porcentaje_batch_index:  4.25 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  169 ds_features:  [['perros', 'requieren'], ['requieren', 'menos']]
# porcentaje_batch_index:  4.28 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  170 ds_features:  [['menos', 'calorías'], ['calorías', 'para']]
# porcentaje_batch_index:  4.3 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  171 ds_features:  [['para', 'vivir'], ['vivir', 'que']]
# porcentaje_batch_index:  4.33 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  172 ds_features:  [['que', 'los'], ['los', 'lobos']]
# porcentaje_batch_index:  4.35 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  173 ds_features:  [['lobos', '.'], ['.', 'su']]
# porcentaje_batch_index:  4.38 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  174 ds_features:  [['su', 'dieta'], ['dieta', 'de']]
# porcentaje_batch_index:  4.4 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  175 ds_features:  [['de', 'sobras'], ['sobras', 'de']]
# porcentaje_batch_index:  4.43 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  176 ds_features:  [['de', 'los'], ['los', 'humanos']]
# porcentaje_batch_index:  4.45 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  177 ds_features:  [['humanos', 'hizo'], ['hizo', 'que']]
# porcentaje_batch_index:  4.48 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  178 ds_features:  [['que', 'sus'], ['sus', 'cerebros']]
# porcentaje_batch_index:  4.51 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  179 ds_features:  [['cerebros', 'grandes'], ['grandes', 'y']]
# porcentaje_batch_index:  4.53 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  180 ds_features:  [['y', 'los'], ['los', 'músculos']]
# porcentaje_batch_index:  4.56 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  181 ds_features:  [['músculos', 'mandibulares'], ['mandibulares', 'utilizados']]
# porcentaje_batch_index:  4.58 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  182 ds_features:  [['utilizados', 'en'], ['en', 'la']]
# porcentaje_batch_index:  4.61 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  183 ds_features:  [['la', 'caza'], ['caza', 'dejaran']]
# porcentaje_batch_index:  4.63 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  184 ds_features:  [['dejaran', 'de'], ['de', 'ser']]
# porcentaje_batch_index:  4.66 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  185 ds_features:  [['ser', 'necesarios'], ['necesarios', '.']]
# porcentaje_batch_index:  4.68 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  186 ds_features:  [['.', 'algunos'], ['algunos', 'expertos']]
# porcentaje_batch_index:  4.71 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  187 ds_features:  [['expertos', 'piensan'], ['piensan', 'que']]
# porcentaje_batch_index:  4.73 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  188 ds_features:  [['que', 'las'], ['las', 'orejas']]
# porcentaje_batch_index:  4.76 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  189 ds_features:  [['orejas', 'flácidas'], ['flácidas', 'de']]
# porcentaje_batch_index:  4.78 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  190 ds_features:  [['de', 'los'], ['los', 'perros']]
# porcentaje_batch_index:  4.81 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  191 ds_features:  [['perros', 'son'], ['son', 'el']]
# porcentaje_batch_index:  4.83 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  192 ds_features:  [['el', 'resultado'], ['resultado', 'de']]
# porcentaje_batch_index:  4.86 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  193 ds_features:  [['de', 'la'], ['la', 'atrofia']]
# porcentaje_batch_index:  4.88 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  194 ds_features:  [['atrofia', 'de'], ['de', 'los']]
# porcentaje_batch_index:  4.91 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  195 ds_features:  [['los', 'músculos'], ['músculos', 'mandibulares']]
# porcentaje_batch_index:  4.94 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  196 ds_features:  [['mandibulares', '.'], ['.', 'anatomía']]
# porcentaje_batch_index:  4.96 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  197 ds_features:  [['anatomía', 'externa'], ['externa', 'diagrama']]
# porcentaje_batch_index:  4.99 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  198 ds_features:  [['diagrama', 'de'], ['de', 'la']]
# porcentaje_batch_index:  5.01 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  199 ds_features:  [['la', 'anatomía'], ['anatomía', 'general']]
# porcentaje_batch_index:  5.04 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  200 ds_features:  [['general', 'de'], ['de', 'un']]
# porcentaje_batch_index:  5.06 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  201 ds_features:  [['un', 'perro'], ['perro', ':']]
# porcentaje_batch_index:  5.09 %
# shape_context:  (2, 2)
#   0%|                                                                                                  | 0/50 [00:27<?, ?it/s]
# Shapes: [torch.Size([4244]), torch.Size([4244])]
# batch_index:  202 ds_features:  [[':', '1.'], ['1.', 'frente']]
# porcentaje_batch_index:  5.11 %
# shape_context:  (2, 2)
# Shapes: [torch.Size([4244]), torch.Size([6366])]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 10
#       4 parameters = {"learning_rate":1e-4,
#       5             "window_length":window_length,
#       6             "batch_size":batch_size,
#       7             "num_epochs":50
#       8 }
#       9 print('Training...')
# ---> 10 lm.train(texto=texto, parametros=parameters)
#      11 lm.save_model()
#
# File /Notebooks/LMsFrom0/src/models.py:160, in FFNLM.train(self, texto, parametros)
#     158 self.optimizer.zero_grad()
#     159 # step 2. compute the output
# --> 160 Y_hat = self.probabilities(ds_features)
#     161 # step 3. compute the loss
#     162 loss = self.loss_func(Y_hat, Y)
#
# File /Notebooks/LMsFrom0/src/models.py:47, in FFNLM.probabilities(self, contexts)
#      39 '''
#      40 Returns the estimated probabilities given a context.
#      41 Input:
#    (...)
#      44     - probabilities (tensor) according to model
#      45 '''
#      46 # Context to one-hot
# ---> 47 coded_context = self.code_context(contexts)
#      48 # Feed network to obtain probabilities
#      49 probabilities = self.FFN(coded_context)
#
# File /Notebooks/LMsFrom0/src/models.py:108, in FFNLM.code_context(self, contexts)
#     106     shapes = [t.shape for t in coded_context]
#     107     print('Shapes:', shapes)
# --> 108     coded_context = torch.stack(coded_context)
#     109 return coded_context
#
# RuntimeError: stack expects each tensor to be equal size, but got [4244] at entry 0 and [6366] at entry 1

# %%
# --------------------------------------
# Finding perplexity
# --------------------------------------
print('Text perplexity:', lm.perplexity(texto))
